# %% [markdown]
# # `runner.ipynb` — universal stage runner
#
# **What this does**
# 1. Mounts Google Drive (Colab) so the cache + outputs persist.
# 2. Sources every code cell from `basic_cells.ipynb` (no copy-paste — single source of truth).
# 3. Reads one `configs/stage_X.yaml` and calls `run_stage(...)`.
# 4. Saves outputs under `<output_dir>/<stage_id>/` (config snapshot, predictions, metrics, plots, summary).
#
# **To run a stage**
# - Drop `configs/stage_X.yaml` into the project folder on Drive.
# - Edit the `CONFIG_PATH` cell below.
# - Runtime → Run all.
#
# **To run a different stage in parallel**
# - Open a second Colab session, same notebook file, point `CONFIG_PATH` at a different config. Cache is shared (Drive); outputs are namespaced by `stage_id`.
#
# **First time only**
# - Run the optional "bulk prefetch" cell once to fill the cache for *all* stages — softer on ISS than letting every stage prefetch its own slice on first run.

# %% [markdown]
# ## 0. Locate the project on Drive
#
# Set `PROJECT_DIR` to the folder containing this notebook + `basic_cells.ipynb` + `configs/`. Default assumes Colab with the project under `MyDrive/moex-hack/`.

# %%
import os
from pathlib import Path

IN_COLAB = "COLAB_GPU" in os.environ or "google.colab" in str(type(globals().get("get_ipython", lambda: None)()))
if IN_COLAB:
    from google.colab import drive
    if not os.path.ismount("/content/drive"):
        drive.mount("/content/drive", force_remount=False)
    PROJECT_DIR = "/content/drive/MyDrive/moex-hack"
else:
    PROJECT_DIR = str(Path.cwd())

os.chdir(PROJECT_DIR)
print(f"PROJECT_DIR = {PROJECT_DIR}")
print("contents:", sorted(os.listdir(PROJECT_DIR)))
# Out:
# PROJECT_DIR = /content/drive/MyDrive/moex-hack
# contents: ['.claude', '.git', '.gitignore', '.mcp.json', '.obsidian', '1B_res.md', '2510.15821v1.pdf', '345_res.md', 'ArenaGo test.md', 'Chronos2_Roma.ipynb', 'Clippings', 'Colab_user_tasks.md', 'LICENSE', 'Pasted image 20260525220744.png', 'Untitled 1.md', 'Untitled.md', 'answers.md', 'ass.json', 'basic_cells.ipynb', 'chat.md', 'configs', 'current_state.md', 'das', 'devdocs.md', 'engines.json', 'etolb', 'exp_plan.md', 'fetch_future_SiH6_24_2021-01-01_2025-12-31.parquet', 'ght.md', 'gp.md', 'index.md', 'm_arenago.txt', 'misha-gitlab-mhack.txt', 'moex_chronos2_pipeline.ipynb', 'my_questions.md', 'pr.md', 'pr_1.md', 'present.md', 'promt.md', 'repo_res', 'runner.ipynb', 'runs', 'scratchpads', 'sec.json', 'stage_B', 'team_repo', 'wiki.md', 'ые']

# %% [markdown]
# ## 1. Source `basic_cells.ipynb`
#
# Executes every code cell from the cell library inside this kernel — no imports, no module packaging, no version drift.

# %%
import json, nbformat
from IPython import get_ipython

BASIC = Path(PROJECT_DIR) / "basic_cells.ipynb"
assert BASIC.exists(), f"missing {BASIC} — copy it next to this notebook"
nb = nbformat.read(str(BASIC), as_version=4)
ip = get_ipython()
n_code = 0
for cell in nb.cells:
    if cell.cell_type == "code":
        ip.run_cell(cell.source)
        n_code += 1
print(f"sourced {n_code} code cells from basic_cells.ipynb")
# Out:
# GPU: Tesla T4  cap=(7, 5)  dtype=torch.float16
# sourced 14 code cells from basic_cells.ipynb

# %% [markdown]
# ## 2. (Optional, one-time) Bulk prefetch all stages
#
# Run once on a fresh Drive cache. Idempotent — safe to re-run.

# %%
# Uncomment to bulk-prefetch every configured stage's data into the cache.
all_cfgs = [load_config(str(p)) for p in sorted(Path("configs").glob("stage_*.yaml"))]
cache_dir = resolve_cache_dir(all_cfgs[0])
manifest = build_prefetch_manifest(all_cfgs)
print(f"manifest size: {len(manifest)} files")
prefetch_all(manifest, cache_dir)
# Out:
# cache_dir = /content/drive/MyDrive/moex_cache
# manifest size: 822 files
# prefetch:   0%|          | 0/822 [00:00<?, ?it/s]
#   EMPTY futures/forts/BRF2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRG2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRJ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRK2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRN2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRQ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRV2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRX2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRF3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRG3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRJ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRK3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRN3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRQ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRV3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRX3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRF4 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRQ5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRU5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRV5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRX5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRZ5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/SiZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDU5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/GDZ5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY futures/forts/BRF9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRG9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRH9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRK9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRM9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRN9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRU9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRV9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRX9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRF0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRG0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRH0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRK0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRM0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRN0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRU0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRV0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRX0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRF7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRG7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRH7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRK7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRM7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRN7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRU7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRV7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRX7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiH9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiM9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiU9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiH0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiM0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiU0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDH9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDM9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDU9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ9 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDH0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDM0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDU0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ0 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDM7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDU7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ7 interval=24 [2021-01-01..2026-04-30]
#   EMPTY futures/forts/BRF1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRG1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRH1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRK1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRM1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRN1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRU1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRV1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRX1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRF2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRG2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRH2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRK2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRM2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRN2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRU2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRV2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRX2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRF3 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRF7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRG7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRH7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRJ7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRK7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRM7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRN7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRQ7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRU7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRV7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRX7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRZ7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiH1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiM1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiU1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiH2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiM2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiU2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/SiZ7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDH1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDM1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDU1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ1 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDH2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDM2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDU2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ2 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDM7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDU7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/GDZ7 interval=60 [2023-01-01..2026-04-30]
#   EMPTY futures/forts/BRF2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiM2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiU2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiM3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiU3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ2 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ3 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH4 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ7 interval=10 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRG0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRH0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRJ0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRK0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRM0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRN0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRQ0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRU0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRV0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRX0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRZ0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRF1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRG1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRH1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRJ1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRK1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRM1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRN1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRQ1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRU1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRV1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRX1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRZ1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiH0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiM0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiU0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiZ0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiH1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiM1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiU1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/SiZ1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDH0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDM0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDU0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDZ0 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDH1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDM1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDU1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/GDZ1 interval=24 [2022-01-01..2022-12-31]
#   EMPTY futures/forts/BRF2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRF7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRG7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRH7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRJ7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRK7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRM7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRN7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRQ7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRU7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRV7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRX7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/BRZ7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiM2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiU2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiM3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiU3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiH4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/SiZ7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ2 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ3 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDH4 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDM7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDU7 interval=24 [2024-05-01..2026-04-30]
#   EMPTY futures/forts/GDZ7 interval=24 [2024-05-01..2026-04-30]

# %% [markdown]
# ## 3. Pick a stage and run
#
# Edit `CONFIG_PATH` to point at the stage you want to run.

# %%
CONFIG_PATH = "configs/stage_0_smoke.yaml"   # <-- edit me

summary = run_stage(CONFIG_PATH)
# Out:
# cache_dir = /content/drive/MyDrive/moex_cache
# prefetch:   0%|          | 0/97 [00:00<?, ?it/s]
#   EMPTY (cached) futures/forts/BRF2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRG2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRJ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRK2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRN2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRQ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRV2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRX2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRF3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRG3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRJ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRK3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRN3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRQ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRV3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRX3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRF4 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRQ5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRU5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRV5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRX5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/BRZ5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/SiZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDH2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDM2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDU2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDZ2 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDH3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDM3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDU3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDZ3 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDU5 interval=24 [2024-01-01..2024-06-30]
#   EMPTY (cached) futures/forts/GDZ5 interval=24 [2024-01-01..2024-06-30]
# panels: price=(127, 12) ret=(127, 12) cov=(127, 20)
# walk-forward: 40 windows
# windows:   0%|          | 0/40 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /tmp/ipykernel_2822/195806788.py:39: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r_s = float(sstats.spearmanr(y_pred, y_true).correlation) if n > 1 else np.nan
# SUMMARY: {
#   "stage_id": "stage_0_smoke",
#   "n_windows": 40,
#   "mean_da_primary": 0.47847222222222224,
#   "median_da_primary": 0.475,
#   "cells_signif_05": 0,
#   "mean_pearson_primary": 0.04241708268017295,
#   "mean_coverage_primary": 0.7638888888888888
# }

# %% [markdown]
# ## 4. Inspect outputs in-line
#
# After `run_stage` finishes, the cell below loads the metrics tables for quick review without leaving the notebook.

# %%
cfg = load_config(CONFIG_PATH)
stage_out = Path(cfg["output_dir"]) / cfg["stage_id"]
print("outputs at:", stage_out)
print("files:", sorted(p.name for p in stage_out.rglob("*") if p.is_file()))

import pandas as pd
metrics = pd.read_csv(stage_out / "metrics.csv")
agg     = pd.read_csv(stage_out / "metrics_aggregate.csv")
print("\n--- aggregate ---");        print(agg.to_string(index=False))
print("\n--- per-cell (head) ---");  print(metrics.head(20).to_string(index=False))

# Display every plot saved by run_stage
from IPython.display import Image, display
for p in sorted((stage_out / "plots").glob("*.png")):
    print(p.name); display(Image(str(p)))

# %% [markdown]
# ## 5. Notes
#
# - **Cache only**: `run_stage` reads from Parquet cache. If a file is missing it errors loudly with the exact missing key — fix the config / re-run §2 prefetch.
# - **Multiple stages in one session**: just re-edit `CONFIG_PATH` and re-run §3 + §4. Outputs are namespaced by `stage_id`; nothing is overwritten across stages.
# - **Long runs**: `run_walk_forward` checkpoints `preds_partial.parquet` every 25 windows.
# - **Path B**: when fine-tuning is wired in, it lives behind a `cfg["path_b"]["enabled"]` flag — same runner.
